# %%
# Out:
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00,  5.63it/s]
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 34
#      25 cv2.putText(frame,
#      26             result['dominant_emotion'],
#      27             (50,50),
#    (...)
#      30             2,
#      31             cv2.LINE_4)
#      32 if ret==True:   # frame is valid
#      33     # show the frame
# ---> 34     cv2.imshow('frame',frame)
#      35     if cv2.waitKey(1) & 0xFF == ord('q'):
#      36         break
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1272: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\manas\anaconda3\lib\site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\manas\anaconda3\lib\site-packages (from opencv-python) (1.24.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\manas\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\manas\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\manas\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\manas\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\manas\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\manas\anaconda3\lib\site-packages)

# %%
import cv2
from matplotlib import pyplot as plt

# Read or capture a frame
frame = cv2.imread('happy.jpg')

# Display the frame using matplotlib
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
plt.show()

# %%
import cv2
from deepface import DeepFace
face_cascade=cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')
cap=cv2.VideoCapture(1)
if not cap.isOpened():
    cap=cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open webcam")
while True:
    ret,frame=cap.read()
    result=DeepFace.analyze(frame,actions=['emotion'],enforce_detection=False)
    from collections import ChainMap

    result = dict(ChainMap(*result))
    
    
    
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    
    faces=face_cascade.detectMultiScale(gray,1.1,4)
    
    for(x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),2)
    font=cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(frame,
                result['dominant_emotion'],
                (50,50),
                font,1,
                (0,0,255),
                2,
                cv2.LINE_4)
    if ret==True:   # frame is valid
        # show the frame
        cv2.imshow('frame',frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00,  5.79it/s]
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 34
#      25 cv2.putText(frame,
#      26             result['dominant_emotion'],
#      27             (50,50),
#    (...)
#      30             2,
#      31             cv2.LINE_4)
#      32 if ret==True:   # frame is valid
#      33     # show the frame
# ---> 34     cv2.imshow('frame',frame)
#      35     if cv2.waitKey(1) & 0xFF == ord('q'):
#      36         break
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1272: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'
